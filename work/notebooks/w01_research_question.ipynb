# %% [markdown]
# <a href="https://colab.research.google.com/github/24pwai0015-max/flyrank-ml-muhammad-arsalan/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/24pwai0015-max/flyrank-ml-muhammad-arsalan/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # I am choosing this lane because the starter data already shows a clear opportunity.
# #  Many pages are declining, and a ranking system can help decide which pages to review
# #  first. In notebook 01 the hand-written rule only reached Precision@50 of 0.24 while
# #  the learned model reached 0.74. That gap shows that better prioritization of pages for
# #   content refresh can improve how limited review time is used. This lane has a clear decision,
# #   a clear action, and enough data to support the next weeks of work.

# %%
# This cell is for CODE (numbers, a query, a check).

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision:** Which pages should be reviewed first for a possible content refresh?
#
# **Who acts:** A content strategist, SEO specialist, or content owner who has limited time to review pages.
#
# **Action:** Open the ranked list, start from the top, and decide whether to refresh, rewrite, or leave the page.
#
# **Cost of a wrong recommendation:**
# - False positive (recommending a healthy page) → wasted review time.
# - False negative (missing a declining page) → continued traffic loss and delayed recovery.
#
# The goal is not to automatically change pages, but to give a better ordered list so human time is spent on higher-value opportunities first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess
import pandas as pd

# Setup for Colab
IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/24pwai0015-max/flyrank-ml-muhammad-arsalan"
REPO_DIR = "flyrank-ml-muhammad-arsalan"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "CSV not found"

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Declining pages (trend_direction == 'down'):", (df["trend_direction"] == "down").sum())
print("Declining rate:", round((df["trend_direction"] == "down").mean(), 3))

print("\nMedian days since last update (declining pages):",
      int(df[df["trend_direction"] == "down"]["days_since_last_update"].median()))
print("Median days since last update (growing pages):",
      int(df[df["trend_direction"] == "up"]["days_since_last_update"].median()))
# Out:
# Working dir: /content/flyrank-ml-muhammad-arsalan
# Total pages: 30000
# Declining pages (trend_direction == 'down'): 16262
# Declining rate: 0.542
#
# Median days since last update (declining pages): 20
# Median days since last update (growing pages): 22

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can claim:**
# - Observed patterns in the data (for example, which pages are currently declining).
# - Directional findings (a ranking method performs better than a simple rule on this sample).
# - Decision-support value (a ranked list can help humans decide where to spend limited review time).
#
# **What I cannot claim:**
# - That the model predicts Google’s ranking algorithm.
# - That refreshing a page will cause traffic to recover (causal proof).
# - That the ranking is perfect or ready for fully automatic decisions.
#
# All recommendations will stay in the language of observed / measured / directional / decision-support.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
